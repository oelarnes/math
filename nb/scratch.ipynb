# %%
from sage.all import *

# %%
def f(x,y,z):
    return x**2 * y - y ** 2 * z

# %%
a = var('a')
t = var('t')

print(f(1, 1, 1))
print(f(3, -1, 1 / 2))
print(f(t, t**2, t**3))
print(f(a, 1, 1-a))
# Out:
# 0
# -19/2
# -t^7 + t^4
# a^2 + a - 1

# %%
"(c): {f(t, t**2, t**3)}."
